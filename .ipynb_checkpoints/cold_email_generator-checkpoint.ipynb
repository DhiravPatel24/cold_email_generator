# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key="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",
    model="llama3-8b-8192",
    temperature=0,
)
response = llm.invoke("first walk in moon")
print(response.content)
# Out:
# The first walk on the Moon was accomplished by NASA astronauts Neil Armstrong and Edwin "Buzz" Aldrin during the Apollo 11 mission in July 1969. Here's a brief overview of their historic journey:
#
# **Apollo 11 Mission Overview**
#
# Apollo 11 was the first manned mission to land on the Moon. The spacecraft, Apollo 11, was launched from Kennedy Space Center in Florida on July 16, 1969, carrying astronauts Neil Armstrong, Edwin "Buzz" Aldrin, and Michael Collins.
#
# **Lunar Module and Descent**
#
# On July 20, Armstrong and Aldrin suited up in their space suits and climbed into the Lunar Module, called Eagle. They separated from the Command Module, Columbia, and descended towards the Moon's surface. The module's computer and pilot, guided by Armstrong, landed the Eagle on the Moon's surface in the Sea of Tranquility at 20:17 UTC on July 20.
#
# **First Step**
#
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

# loader = WebBaseLoader("https://www.crestdata.ai/careers/open-positions/key-account-manager-security")
# loader = WebBaseLoader("https://www.iflair.com/jobs/javascript-developer/")
loader = WebBaseLoader("https://www.iflair.com/jobs/php-developer/")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
#    Latest PHP Developer and Fresher Jobs in Ahmedabad - Iflair
#
#
# Services
#
# E-Commerce Development
# Back End Development
# Front End Development
# CMS Development
# Mobile Application
# Cloud Services
# Digital Marketing
# Quality Assurance
# E-Commerce Development
#  Magento
#  Woocommerce
#  Shopify
#  Prestashop
#
# E-commerce Solutions that delivers ROI.We offer omnichannel ecommerce solutions for your online store.
# Get A Free Quote
# Back End Development
#  Laravel Development
#  NodeJS Developers
#  Next JS Development
#  Nuxt.js Development
#  MeanJs Development
#  Hire API Developer
#  CodeIgniter Development
#  Custom PHP Development
#  CakePHP Development
#
# The Coding Expertise.Our experts’ coding excellence builds robust web applications.
# Get A Free Quote
# Front End Development
#  Angular
#  React Developer
#  Vue JS
#  Full Stack
#  Tailwind CSS
#  HTML 5
#  CSS3
#  UI/UX Design
#  Javascript
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
job_description = res.content
type(res.content)
print(res.content)
# Out:
# Here is the extracted job posting in JSON format:
#
# ```
# [
#   {
#     "role": "PHP Developer",
#     "experience": "Fresher/1-3 years",
#     "skills": ["Laravel", "Symphony", "CodeIgniter", "MVC design patterns", "AJAX/JavaScript/Json/Jquery", "Creating API and CSS", "Apache, MySql and their declarative query languages", "Git", "Common third party APIs (Google, Facebook, eBay)"],
#     "description": "Good Experience of PHP web frameworks like Laravel, Symphony, CodeIgniter is must. Understanding of MVC design patterns. Knowledge for AJAX/JavaScript/Json/Jquery/Creating API and CSS is preferable. Good knowledge of relational databases of Apache, MySql and their declarative query languages. Proficient understanding of code versioning tools, such as Git. Experience in common third party APIs (Google, Facebook, eBay) and developing web services."
#   }
# ]
# ```
#
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)

if isinstance(json_res, list) and len(json_res) == 1:
    json_res = json_res[0]

# Now you can work with json_res as a dictionary
print(type(json_res))
print(json_res)
# Out:
# <class 'dict'>
# {'role': 'PHP Developer', 'experience': 'Fresher/1-3 years', 'skills': ['Laravel', 'Symphony', 'CodeIgniter', 'MVC design patterns', 'AJAX/JavaScript/Json/Jquery', 'Creating API and CSS', 'Apache, MySql and their declarative query languages', 'Git', 'Common third party APIs (Google, Facebook, eBay)'], 'description': 'Good Experience of PHP web frameworks like Laravel, Symphony, CodeIgniter is must. Understanding of MVC design patterns. Knowledge for AJAX/JavaScript/Json/Jquery/Creating API and CSS is preferable. Good knowledge of relational databases of Apache, MySql and their declarative query languages. Proficient understanding of code versioning tools, such as Git. Experience in common third party APIs (Google, Facebook, eBay) and developing web services.'}

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio1")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
print(job['skills'])
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# ['Laravel', 'Symphony', 'CodeIgniter', 'MVC design patterns', 'AJAX/JavaScript/Json/Jquery', 'Creating API and CSS', 'Apache, MySql and their declarative query languages', 'Git', 'Common third party APIs (Google, Facebook, eBay)']
# [[{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/kotlin-backend-portfolio'},
#   {'links': 'https://example.com/android-portfolio'}],
#  [{'links': 'https://example.com/full-stack-js-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/typescript-frontend-portfolio'},
#   {'links': 'https://example.com/full-stack-js-portfolio'}],
# ...

# %%
job=json_res
job['skills']
# Out:
# ['Laravel',
#  'Symphony',
#  'CodeIgniter',
#  'MVC design patterns',
#  'AJAX/JavaScript/Json/Jquery',
#  'Creating API and CSS',
#  'Apache, MySql and their declarative query languages',
#  'Git',
#  'Common third party APIs (Google, Facebook, eBay)']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Dhirav, a business development executive at iFlair. iFlair is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of iFlair 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase iFlair's portfolio: {link_list}
        Remember you are Dhirav, BDE at iFlair. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert PHP Development Services for Your Project
#
# Dear [Client],
#
# I came across your job posting for a PHP Developer and was impressed by the requirements. As a Business Development Executive at iFlair, I'd like to introduce our company's expertise in delivering tailored PHP development solutions.
#
# Our team of experienced developers has a strong background in PHP web frameworks like Laravel, Symphony, and CodeIgniter. We understand the importance of MVC design patterns and have hands-on experience with AJAX/JavaScript/Json/Jquery, Creating API and CSS. Our proficiency in relational databases, including Apache, MySql, and their declarative query languages, ensures seamless data management.
#
# ...
